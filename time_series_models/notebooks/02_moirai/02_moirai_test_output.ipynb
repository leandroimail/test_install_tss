# %% [markdown]
# # Teste do Modelo 2: Salesforce Moirai com Covariáveis

# %%
# !python main.py
# Out:
# Carregando dados...
# Dados históricos e covariáveis futuras carregados e preparados.
# Número de covariáveis: 2
#
# Usando dispositivo: cpu
# --- Testando Salesforce Moirai com Covariáveis ---
# Rodando previsão para 14 passos...
# Previsão concluída!
# Tamanho da previsão verificado com sucesso.
# Amostra da previsão (média):
# [110.93338 144.0536   96.09535  79.81821  95.75832]
#
# Teste do Moirai concluído.
# Exception ignored in: <generator object PyTorchPredictor.predict at 0x7fef198aa240>
# Traceback (most recent call last):
#   File "/app/time_series_models/notebooks/02_moirai/.venv/lib/python3.12/site-packages/gluonts/torch/model/predictor.py", line 89, in predict
#   File "/app/time_series_models/notebooks/02_moirai/.venv/lib/python3.12/site-packages/torch/autograd/grad_mode.py", line 85, in __exit__
# AttributeError: 'NoneType' object has no attribute 'set_grad_enabled'

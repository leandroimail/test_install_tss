# %% [markdown]
# # Teste do Modelo 6: IBM Flowstate (granite-tsfm)

# %%
# !python main.py
# Out:
# Carregando dados...
# Dados históricos carregados.
#
# Usando dispositivo: cpu
#
# --- Testando IBM Flowstate ---
#
# AVISO: O modelo Flowstate está atualmente bloqueado.
# A API espera apenas um único canal de entrada ('single variate'),
# o que impede a inclusão de covariáveis através da abordagem de canal multivariado.
# Pulando a execução do Flowstate.

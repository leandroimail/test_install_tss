# %% [markdown]
# # Teste do Modelo 1: Amazon Chronos com Covariáveis

# %%
# !python main.py
# Out:
# Carregando dados...
# Dados históricos carregados:
#     timestamp      target  day_of_week  month
# 95 2023-04-06   91.026088            3      4
# 96 2023-04-07   82.740630            4      4
# 97 2023-04-08   87.401396            5      4
# 98 2023-04-09  100.150267            6      4
# 99 2023-04-10  112.014606            0      4
#
# Covariáveis futuras carregadas:
#    timestamp  day_of_week  month
# 0 2023-04-11            1      4
# 1 2023-04-12            2      4
# 2 2023-04-13            3      4
# 3 2023-04-14            4      4
# 4 2023-04-15            5      4
#
# Usando dispositivo: cpu
# --- Testando Amazon Chronos com Covariáveis ---
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
# Formato do dataframe combinado: (114, 5)
# Rodando previsão para 14 passos...
# ...

# %% [markdown]
# # Teste do Modelo 7: IBM TinyTimeMixer

# %%
# !.venv/bin/python main.py
# Out:
# Carregando dados...
# Dados de treino (y): (100,)
# Dados de treino (X): (100, 2)
# Covariáveis futuras (X): (14, 2)
#
# Instanciando e treinando o modelo...
# Ocorreu um erro detalhado:
# Traceback (most recent call last):
#   File "/app/time_series_models/notebooks/07_tinytimemixer/main.py", line 67, in main
#     model.fit(y_train, X=X_train)
#   File "/app/time_series_models/notebooks/07_tinytimemixer/.venv/lib/python3.12/site-packages/sktime/forecasting/base/_base.py", line 388, in fit
#     fh = self._check_fh(fh)
#          ^^^^^^^^^^^^^^^^^^
#   File "/app/time_series_models/notebooks/07_tinytimemixer/.venv/lib/python3.12/site-packages/sktime/forecasting/base/_base.py", line 1945, in _check_fh
#     raise ValueError(
# ValueError: The forecasting horizon `fh` must be passed to `fit` of TinyTimeMixerForecaster, but none was found. This is because fitting of the forecaster TinyTimeMixerForecaster depends on `fh`.

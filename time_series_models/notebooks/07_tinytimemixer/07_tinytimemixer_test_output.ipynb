# %% [markdown]
# # Teste do Modelo 7: IBM TinyTimeMixer

# %%
# !python main.py
# Out:
# Carregando dados...
# Dados históricos carregados.
#
# --- Testando IBM TinyTimeMixer com Covariáveis ---
#
# AVISO: O modelo TinyTimeMixer está atualmente bloqueado neste ambiente.
# A importação da biblioteca 'transformers' está a falhar dentro do script,
# apesar de parecer estar instalada corretamente. Isto impede a execução do modelo.
# Pulando a execução do TinyTimeMixer.

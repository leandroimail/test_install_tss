# %% [markdown]
# # Teste do Modelo 3: TabPFN-TS com Covariáveis

# %%
# !python main.py
# Out:
# Carregando dados...
# Dados de treino e teste preparados.
# Erro de importação detalhado: cannot import name 'TabPFNTimeSeriesRegressor' from 'tabpfn_time_series' (/app/time_series_models/notebooks/03_tabpfn_ts/.venv/lib/python3.12/site-packages/tabpfn_time_series/__init__.py)

# %%
# !python main.py
# Out:
# Carregando dados...
# Dados carregados com sucesso. Colunas: Index(['target', 'day_of_week', 'month'], dtype='object')
# DataFrame preparado para o modelo:
#                         target  day_of_week  month
# 2024-07-11 20:00:00  53.816207            6      1
# 2024-07-11 21:00:00  64.961644            0      1
# 2024-07-11 22:00:00  65.556854            1      1
# 2024-07-11 23:00:00  56.888397            2      1
# 2024-07-12 00:00:00  48.429107            3      1
#
# Carregando modelo...
# Ocorreu um erro detalhado:
# Traceback (most recent call last):
#   File "/app/time_series_models/notebooks/08_patchtst/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py", line 402, in hf_raise_for_status
#     response.raise_for_status()
#   File "/app/time_series_models/notebooks/08_patchtst/.venv/lib/python3.12/site-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# ...
